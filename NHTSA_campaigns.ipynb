# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
recall_df = pd.read_csv("/Users/seanm/Desktop/Bootcamp/p1_team8/Recalls_Data.csv")

# %%
recall_df.head()
# Out:
#   Report Received Date   NHTSA ID  \
# 0           12/05/2024  24V911000
# 1           12/05/2024  24V909000
# 2           12/03/2024  24V907000
# 3           12/03/2024  24V906000
# 4           12/03/2024  24V908000
#
#                                          Recall Link  \
# 0  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 1  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 2  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 3  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 4  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                                Manufacturer  \
# 0  Toyota Motor Engineering & Manufacturing
# 1                 BMW of North America, LLC
# 2                        Nova Bus (US) Inc.
# 3                 International Motors, LLC
# 4                       PACCAR Incorporated
#
#                                              Subject  \
# 0  Loose Bolts on Brake Caliper and Wheel Hub Bea...
# ...

# %%
recall_df.columns
# Out:
# Index(['Report Received Date', 'NHTSA ID', 'Recall Link', 'Manufacturer',
#        'Subject', 'Component', 'Mfr Campaign Number', 'Recall Type',
#        'Potentially Affected', 'Recall Description', 'Consequence Summary',
#        'Corrective Action', 'Park Outside Advisory ', 'Do Not Drive Advisory',
#        'Completion Rate % (Blank - Not Reported)'],
#       dtype='object')

# %%
recall_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28592 entries, 0 to 28591
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Report Received Date                      28592 non-null  object
#  1   NHTSA ID                                  28592 non-null  object
#  2   Recall Link                               28592 non-null  object
#  3   Manufacturer                              28592 non-null  object
#  4   Subject                                   28592 non-null  object
#  5   Component                                 28592 non-null  object
#  6   Mfr Campaign Number                       28545 non-null  object
#  7   Recall Type                               28592 non-null  object
#  8   Potentially Affected                      28551 non-null  float64
#  9   Recall Description                        26191 non-null  object
# ...
